# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset
df = pd.read_csv("Music-Dataset.csv")

# Create a Pair Plot with selected columns
sns.pairplot(df[['danceability', 'energy', 'valence', 'acousticness', 'duration_ms']])

# Show the plot
plt.show()
