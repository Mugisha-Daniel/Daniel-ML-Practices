# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("Phone-Prices-Dataset.csv")

x = df["Model"]
y = df["Price"]

plt.xlabel("Model")
plt.ylabel("Price($)")
plt.bar(x, y)
plt.show()
