# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset = pd.read_csv("Customers-Dataset.csv")
data_hist = np.random.randn(1000)

plt.hist(data_hist, bins=30, color='skyblue', edgecolor='black')

plt.title('Histogram')
plt.xlabel('Age')
plt.ylabel('income')

plt.show()
